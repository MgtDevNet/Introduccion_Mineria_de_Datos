# %% [markdown]
# # Ingeniería de características.
#
# Definición.
# .
# .
# .
# otras ideas
# .
# .
# .
#
#
#
# ### Normalización Min-Max
# Esta normalización funciona al ver cuánto más grande es el valor actual del valor mínimo min(X) y escala esta diferencia por el rango.
#
# -> Estos valores de normalizcaión min-max van de 0 a 1.
#
#
# *PSI:* Population Stability Index, verifica la distribución de datos del entrenamiento y el test y aplicación. Y esto da a concer carátetrísticas del desempeño de este.
#
# ### Normailización Z-score.
# Los valros para un atributo X, se normalizan en base a la media y la desviación estandar de X. En caso que sea una distribución con colas pesadas entonces lo mejor sería usar el Z-score modificado.
#
#
# ### Normalización Decimal Scaling
#
#
# _IMPORTANTE: NOTE QUE LAS ESTRATÉGIAS DE NORMALIZACIÓN MANTIENEN LA MISMA DISTRIBUCIÓN, SESGO, VARIABILIDAD, ETC. LO QUE CAMBIA ES EL RANGO EN EL QUE SE MUEVEN LOS DATOS. ES DECIR, LA ESCALA DE MEDIDA, QUE SI ES DIFERNTE ENTRE VARIABLES PUEDE DAÑAR LAS PREDICCIONES O EN SI LAS CAPACIDADES DE PREDICCIÓN._
#
#
# ##  - Escalados Robustos.
#
# ## Transformaciónes para lograr normalidad.
#
# ## Discretización Binning.
#
# *Es necesario que toda decisión debe tener una explicación, razón y sutentación técnica de la toma.*
