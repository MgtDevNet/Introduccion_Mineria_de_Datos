# %% [markdown]
# Clase del 12 y 14 de mayo
# # Práctica: Reducción de Dimensionalidad e Ingeniería de Características
# **Introducción a la Minería de Datos — Semana 7**
# Verónica Guarín Escudero · Departamento de Estadística · Universidad Nacional de Colombia
#
# ---
#
# ## Objetivo del notebook
#
# Este laboratorio pone en práctica los conceptos de la Semana 7 usando el dataset **Iris** como hilo conductor. Al finalizar, deberías ser capaz de:
#
# - Identificar y eliminar columnas problemáticas (datos faltantes, baja varianza, alta correlación).
# - Aplicar PCA para reducir dimensiones y visualizar el resultado.
# - Medir la importancia de variables con Random Forest.
# - Normalizar variables numéricas (Min-Max, Z-Score, Decimal Scaling, Robusto).
# - Discretizar variables continuas (binning por igual ancho, igual frecuencia y basado en entropía).
# - Recodificar variables categóricas con One-Hot Encoding.
# - Calcular el Information Value (IV) y el Weight of Evidence (WoE) para selección supervisada de variables.
#
# ## Estructura del notebook
#
# | Sección | Tema |
# |---------|------|
# | 1 | Librerías y carga de datos |
# | 2 | Exploración inicial |
# | 3 | **Reducción de Dimensionalidad** |
# | 3.1 | Eliminar columnas con datos faltantes |
# | 3.2 | Low Variance Filter |
# | 3.3 | Columnas altamente correlacionadas |
# | 3.4 | Variables importantes con Random Forest |
# | 3.5 | Análisis de Componentes Principales (PCA) |
# | 4 | **Ingeniería de Características** |
# | 4.1 | Normalización (Min-Max, Z-Score, Decimal Scaling, Robusto) |
# | 4.2 | Discretización (Binning: igual ancho, igual frecuencia) |
# | 4.3 | Discretización basada en entropía |
# | 4.4 | Recodificación de variables categóricas (One-Hot Encoding) |
# | 5 | Resumen comparativo |
# | 6 | **Ñapa: Information Value (IV) y Weight of Evidence (WoE)** |

# %% [markdown]
# ---
# ## 1. Librerías y carga de datos

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

#sklearn datasets tienen diferentes dataframes para practicar
#RECORDEMOS QUE SICKIT-LEARN TIENE UNA ESTRUCTURA ORIENTADA A
# OBJETOS
from sklearn.datasets import load_iris #cargar datos iris

#cargar función de PCA
from sklearn.decomposition import PCA 

#cargar algoritmo de randomforest
from sklearn.ensemble import RandomForestClassifier 

#importar funciones de procesamiento para la ingeniería de características
from sklearn.preprocessing import (
    MinMaxScaler, StandardScaler, RobustScaler,
    KBinsDiscretizer, OneHotEncoder
)

# funciones de modelación:

#función para separar los datos en train y test
from sklearn.model_selection import train_test_split

#métricas de desempeño
from sklearn.metrics import accuracy_score

#función de árbol de decisión
from sklearn.tree import DecisionTreeClassifier

#estadísticos
from scipy.stats import pearsonr

# Configuración visual
sns.set_theme(style='whitegrid', palette='Set2')
plt.rcParams['figure.dpi'] = 100

print('✅ Librerías cargadas correctamente.')
#FALTA PONER QUE LOS GRÁFICOS QUEDEN COMO EN ARTÍCULOS.
# Out:
# ✅ Librerías cargadas correctamente.

# %% [markdown]
# ---
# ## 2. Exploración inicial del dataset Iris
#
# El dataset **Iris** contiene 150 observaciones de flores con 4 variables numéricas (dimensiones en cm del sépalo y pétalo) y una variable objetivo de 3 clases: *setosa*, *versicolor* y *virginica*.
#
# > 💡 Aunque Iris es un dataset limpio, a lo largo del notebook **simularemos** condiciones reales (datos faltantes, variables redundantes, variables sesgadas) para que puedas ver cada técnica en acción.
#
# ![iris](../imagenes/iris.png)

# %%
# Cargar el dataset
iris = load_iris()

# %%
print(type(iris)) #notese que es una instancia de scikit learn
#y pues esto tiene sus atributos

#print(iris.keys()) #estos son los atributos que pueden usarse. 

#print(iris.feature_names) #para ver las columnas

#print(iris.target) #para ver la variable objetivo

#print(iris.target_names) # variable objetivo con string

#Hay unas cosas que son atributos y lo otr que son métodos se les
#pone el paréntesis
#print(iris.items())}



print(iris.data[0:5]) #para ver las primeras 5 filas de los datos

#print(type(iris.data))
# Out:
# <class 'sklearn.utils._bunch.Bunch'>
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]]

# %%
#Lo volvemos un data frame, indicando los datos
# y el nombre de las columnas 
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)

#definindo la variable objetivo
df['species'] = iris.target

# Mapear etiquetas numéricas a nombres de especies.
#importante: notese que no se está usando la función
#global map() de python, sino el método .map() propio de una
#serie de pandas. 
#Este método sirve para transformar o sustituir los valores
#de una columna usando un diccionario de mapeo

#diccionario de mapeo
species_map = {0: 'setosa', 1: 'versicolor', 2: 'virginica'}

#a cada valor de la columa 'species' se le asigna el
# valor correspondiente en el diccionario
df['species_name'] = df['species'].map(species_map)

# A diferencia de un for, .map() está optimizada en C (vectorizado)
# por lo que es muy rápido.
# Si en la columnna aparece un valor que no está en las llaves del diccionario
# .map no dará error sino que asigna un NaN en ese registro en la nueva
# columna. 

print(f'Dimensiones: {df.shape}  →  {df.shape[0]} filas × {df.shape[1]} columnas')
df.head()
# Out:
# Dimensiones: (150, 6)  →  150 filas × 6 columnas
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    species species_name
# 0        0       setosa
# 1        0       setosa
# 2        0       setosa
# 3        0       setosa
# 4        0       setosa

# %%
type(df['species']) # serie de pandas
type(df[['species']]) # dataframe de pandas
# Out:
# pandas.DataFrame

# %%
# Estadísticas descriptivas de variables numéricas
# redondeadas a 4 decimales. 
df.describe().round(4)
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count           150.0000          150.0000           150.0000
# mean              5.8433            3.0573             3.7580
# std               0.8281            0.4359             1.7653
# min               4.3000            2.0000             1.0000
# 25%               5.1000            2.8000             1.6000
# 50%               5.8000            3.0000             4.3500
# 75%               6.4000            3.3000             5.1000
# max               7.9000            4.4000             6.9000
#
#        petal width (cm)   species
# count          150.0000  150.0000
# mean             1.1993    1.0000
# std              0.7622    0.8192
# min              0.1000    0.0000
# 25%              0.3000    0.0000
# 50%              1.3000    1.0000
# 75%              1.8000    2.0000
# max              2.5000    2.0000

# %%
# Pairplot: distribución y relaciones entre variables por especie

#matríz de gráficos que permite visulaizra como se comportan todas las características 
# al mismo tiempo, y permite ver la relación entre ellas.
sns.pairplot(df, hue='species_name', vars=iris.feature_names, diag_kind='kde')

#sns.pairplot() crea una grilla NxN(N: # de variables) con 
#vars=iris.feature_names indica que se van a usar todas las columnas numéricas
#hue='species_name' indica que se van a colorear los puntos según la especie
#diag_kind='kde' indica que en la diagonal se va a graficar la densidad de cada variable.

#y=1.02 es sube ligeramente el texto para que no se superponga
#en los gráficos. 
plt.suptitle('Pairplot del dataset Iris', y=1.02)

#para renderizar la figura
plt.show()

# %% [markdown]
# densidades:
#
# - Parece que en promedio la flor setosa tiene menos longitud del sepalo. Luego, respecto a la anchura del sépalo, parece ser que setosa tiene valores más grandes que versicolor y virgínica; las cuales, parecen tener iguales valores de anchura se sépalo. Respecto al pétalo, setosa parece tener menores valores tanto en longitud como en ancho y parece que virgínica en promedio tiene los pétalos de mayor longitud y anchura.
#
# - Con respecto a la dispersión de los datos, la longitud y anchura del sépalo muestra una relación lineal creciente entre todos los tipos de flores, sobre todo en setosa pues en virginica y en versicolor no es tan claro. Luego, la longitud del pétalo no parece tener relación ni con la longitud ni la anchura de la flor setosa pero para las otras dos especies si parece tener una relación lineal creciente. Para el ancho del pétalo parece algo bastante similar pues no hay una relación clara respecto a las dimensiones del sépalo en la especie setosa pero parece que si hay una relación de en las otras especies. Por último, es evidente que para todas las especies de flores hay una relación creciente entre el ancho y la longitud de los pétalos.

# %% [markdown]
# ---
# ## 3. Reducción de Dimensionalidad
#
# La **reducción de dimensionalidad** consiste en remover atributos que no aportan información relevante. Esto combate la *maldición de la dimensionalidad*, que trae problemas como:
#
# - **Espacio disperso**: las observaciones quedan muy separadas entre sí.
# - **Dificultad para visualizar**: más de 3 dimensiones no se pueden graficar directamente.
# - **Sobreajuste**: modelos más complejos se ajustan al ruido en lugar del patrón real.
# - **Costo computacional**: más variables → mayor tiempo de entrenamiento.
#
# Veremos 5 estrategias: eliminación por datos faltantes, filtro de varianza baja, eliminación de pares correlacionados, importancia con Random Forest y PCA.

# %% [markdown]
# ### 3.1 Eliminar columnas con datos faltantes
#
# **Concepto:** si una columna tiene un porcentaje alto de valores nulos (p. ej. más del 40 %) y no es posible imputar los valores faltantes de forma confiable, es mejor eliminarla.
#
# **Criterio típico:** eliminar columnas con más del 40 % de valores nulos (puedes ajustar este umbral según tu problema).
#
# Para demostrar la técnica, añadimos artificialmente columnas con muchos nulos al dataframe original.

# %%
len(df) #cantidad de filas
np.random.rand(10) #valores aleatorios entre 0 y 1
np.random.rand(10) < 0.70 #valores aleatorios entre 0 y 1, comparados con 0.7
#como es una distribución uniforme  debería cumplir el 70% de las veces 

np.where(np.random.rand(10) < 0.70, np.nan, np.random.rand(10)) # si cumple, asigna un NaN, 
# sino asigna un valor aleatorio entre 0 y 1.,
# Out:
# array([0.07381916, 0.6113608 ,        nan,        nan, 0.47761882,
#               nan,        nan, 0.15802914,        nan,        nan])

# %%
type(df.isnull()) #retorna el data frame pero con booelanos para ver si 
# hay valores nulos o no.

df.isnull().sum() #suma de valores nulos por columna.
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# species              0
# species_name         0
# dtype: int64

# %%
# --- Simulación de datos faltantes ---
np.random.seed(42)# Semilla
df_sim = df.copy() #siempre trabajar sobre una copia.
 
# Columna con 70 % de nulos → debería eliminarse
# como se pone de argumento el len(df_sim) entonces se hacen
# los 150 valores.
df_sim['col_70pct_nulos'] = np.where(
    np.random.rand(len(df_sim)) < 0.70, np.nan, np.random.rand(len(df_sim))
)

#Acá hacemos lo mismo pero con 20% de nulos. 
# Columna con 20 % de nulos → se conserva (por debajo del umbral)
df_sim['col_20pct_nulos'] = np.where(
    np.random.rand(len(df_sim)) < 0.20, np.nan, np.random.rand(len(df_sim))
)

# Mostrar porcentaje de nulos por columna
pct_nulos = df_sim.isnull().mean().round(3) * 100
print('Porcentaje de valores nulos por columna:')
print(pct_nulos.to_string())
# Out:
# Porcentaje de valores nulos por columna:
# sepal length (cm)     0.0
# sepal width (cm)      0.0
# petal length (cm)     0.0
# petal width (cm)      0.0
# species               0.0
# species_name          0.0
# col_70pct_nulos      70.0
# col_20pct_nulos      24.7

# %%
# --- Aplicar el criterio de eliminación ---
UMBRAL_NULOS = 0.40  # 40 %

cols_antes = df_sim.shape[1] #número de columnas

#hacer un filtro, se escogen todas las filas y las columnas que
#  cumplan con el criterio de nulos
df_sin_nulos = df_sim.loc[:, df_sim.isnull().mean() < UMBRAL_NULOS]

cols_despues = df_sin_nulos.shape[1]

#esto es una diferencia de conjuntos
cols_eliminadas = set(df_sim.columns) - set(df_sin_nulos.columns)
print(f'Columnas antes: {cols_antes}')
print(f'Columnas eliminadas: {cols_eliminadas}')
print(f'Columnas después: {cols_despues}')
# Out:
# Columnas antes: 8
# Columnas eliminadas: {'col_70pct_nulos'}
# Columnas después: 7

# %% [markdown]
# ### 3.2 Low Variance Filter (Filtro de Varianza Baja)
#
# **Concepto:** una variable con varianza cero o muy baja no discrimina entre observaciones — todos los valores son iguales o casi iguales. Eliminar estas variables no produce pérdida de información útil.
#
# $\rightarrow$**Importante:**$\leftarrow$ los datos deben **normalizarse** antes de comparar varianzas, para que el umbral sea independiente de la escala de cada variable.
#
# **Criterio:** eliminar columnas cuya varianza (sobre datos normalizados) esté por debajo de un umbral `t`.

# %%
# Trabajamos solo con las columnas numéricas de Iris
X = df[iris.feature_names].copy()

# --- Paso 1: normalizar con Min-Max para que varianzas sean comparables ---
scaler_mm = MinMaxScaler() #creamos una instancia de la clase MinMaxScaler
# .fit_transform() es un método que transforma los datos. Siendo X el data frame 
X_norm = pd.DataFrame(scaler_mm.fit_transform(X), columns=X.columns)

# --- Paso 2: simular una columna constante (varianza = 0) ---
X_norm['constante'] = 1.0 #crea una columna con el mismo valor
X_norm['casi_constante'] = np.where(np.random.rand(len(X_norm)) < 0.95, 0.5, 0.51) # crear una columna
#que sigue una distribución uniforme cada elemento tiene un 95% de probabilidad de ser 0.5 y un 5% de probabilidad de ser 0.51.

# --- Paso 3: calcular varianzas ---
varianzas = X_norm.var().round(5)
print('Varianza de cada columna (datos normalizados):')
print(varianzas.to_string())

# Visualizar varianzas
fig, ax = plt.subplots(figsize=(8, 4))
varianzas.plot(kind='bar', ax=ax, color='steelblue', edgecolor='white')
UMBRAL_VAR = 0.01
ax.axhline(UMBRAL_VAR, color='red', linestyle='--', label=f'Umbral = {UMBRAL_VAR}')
ax.set_title('Varianza por columna (datos normalizados)')
ax.set_ylabel('Varianza')
ax.legend()
plt.xticks(rotation=30, ha='right')
plt.tight_layout()
plt.show()
# Out:
# Varianza de cada columna (datos normalizados):
# sepal length (cm)    0.05291
# sepal width (cm)     0.03298
# petal length (cm)    0.08952
# petal width (cm)     0.10087
# constante            0.00000
# casi_constante       0.00000

# %% [markdown]
# Es recomendable que el umbral sea bajo, en este caso se pone 0.1 y la verdad todas las variables tienen una variación bastante baja. Ojo, el contexto es importante y pueden haber casos que la variabilidad sea muy baja pero que la variable sea importante. Además, si hay duda de si dejas una columna o no, lo mejor será dejarla.

# %%
# --- Aplicar filtro ---
#Se crea una lista de los índices. 
cols_alta_var = varianzas[varianzas >= UMBRAL_VAR].index.tolist()
cols_baja_var = varianzas[varianzas < UMBRAL_VAR].index.tolist()

print(f'Columnas eliminadas por baja varianza: {cols_baja_var}')
print(f'Columnas conservadas: {cols_alta_var}')
# Out:
# Columnas eliminadas por baja varianza: ['constante', 'casi_constante']
# Columnas conservadas: ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']

# %% [markdown]
# ### 3.3 Columnas altamente correlacionadas
#
# **Concepto:** si dos variables tienen una correlación muy alta entre sí, una de ellas es redundante. Eliminar una no disminuye drásticamente la información disponible.
#
# **Procedimiento:**
# 1. Calcular la matriz de correlaciones (Pearson para variables continuas).
# 2. Fijar un umbral (p. ej. 0.80).
# 3. Para cada par con correlación ≥ umbral, conservar la variable que tenga **menor** correlación promedio con el resto. Pues sería la que mayor variabilidad explica. Menor correlación es mejor (Entre covaraibles, obvio una correlación alta con al variable respuesta es ideal.)

# %%
X_features = df[iris.feature_names]

# Matriz de correlaciones
X_features.corr().round(3)
# Out:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)              1.000            -0.118              0.872
# sepal width (cm)              -0.118             1.000             -0.428
# petal length (cm)              0.872            -0.428              1.000
# petal width (cm)               0.818            -0.366              0.963
#
#                    petal width (cm)
# sepal length (cm)             0.818
# sepal width (cm)             -0.366
# petal length (cm)             0.963
# petal width (cm)              1.000

# %%
X_features = df[iris.feature_names]

# Matriz de correlaciones
corr_matrix = X_features.corr().round(3)

# Visualizar heatmap
fig, ax = plt.subplots(figsize=(6, 5))
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))  # Mostrar solo triángulo inferior
sns.heatmap(
    corr_matrix, annot=True, fmt='.2f', cmap='coolwarm',
    mask=mask, vmin=-1, vmax=1, ax=ax,
    linewidths=0.5, square=True
)
ax.set_title('Matriz de Correlaciones — Dataset Iris')
plt.tight_layout()
plt.show()

# %%
type(X_features.corr()) #dta frame de las correlaciones
np.triu(np.ones([3,3]))
np.triu(np.ones([3,3]), k=1)
np.triu(np.ones([3,3]), k=1).astype(bool)
# Out:
# array([[False,  True,  True],
#        [False, False,  True],
#        [False, False, False]])

# %%
prueba = X_features.corr().where(np.triu(np.ones(X_features.corr().shape), k=1).astype(bool))
prueba #siguen siendo un data frame
#notese que el índice también es el nombre de las variables
# Out:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)                NaN          -0.11757           0.871754
# sepal width (cm)                 NaN               NaN          -0.428440
# petal length (cm)                NaN               NaN                NaN
# petal width (cm)                 NaN               NaN                NaN
#
#                    petal width (cm)
# sepal length (cm)          0.817941
# sepal width (cm)          -0.366126
# petal length (cm)          0.962865
# petal width (cm)                NaN

# %%
prueba.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)'],
#       dtype='str')

# %%
prueba.index[prueba['petal length (cm)'] >= 0.8].tolist() #retorna un lista de los índices que cumplen la condición
#teniendo en cuenta que el índice es el nombre de las variables, entonces se puede usar para obtener los nombres de las variables correlacionadas.
# Out:
# ['sepal length (cm)']

# %%
aux = X_features.corr()
aux["sepal length (cm)"]
aux["sepal length (cm)"].drop("sepal length (cm)")  #elimina la correlación consigo misma
# Out:
# sepal width (cm)    -0.117570
# petal length (cm)    0.871754
# petal width (cm)     0.817941
# Name: sepal length (cm), dtype: float64

# %%
def eliminar_correlacionadas(df_num, umbral=0.80):
    """
    Dado un DataFrame numérico, identifica pares de columnas con correlación
    absoluta >= umbral y elimina la que tenga mayor correlación promedio con el
    resto (la más 'redundante').

    Retorna:
        cols_conservar  : lista de columnas a conservar
        cols_eliminar   : lista de columnas eliminadas
    """
    corr = df_num.corr().abs() #obtener valor abs de la correlaciones
    
    # Triangulo superior sin diagonal de la matriz de correlaciones
    # np.ones(corr.shape) crea una matriz de unos del mismo tamaño que la matriz de correlación.
    # pero llena de unos. 
    # np.triu() toma el triángulo superior de la matriz de unos, dejando el resto en cero.
    # el k=1 indica que se excluye la diagonal (correlación de una variable consigo misma)
    upper = corr.where(np.triu(np.ones(corr.shape), k=1).astype(bool))
    # todos los valores de true se dejan, los otros se ponene NaN.

    #se crea un conjunto para almacenar las columnas a eliminar, ya que no queremos duplicados
    cols_eliminar = set()

    #se recorren las columnas
    for col in upper.columns:

        # Acá obtenemos el par de la columna 'col' que tiene correlación >= umbral.
        # pues en la matriz de correlación los índices son los nombres de las variables,
        # entonces se puede usar para obtener los nombres de las variables correlacionadas. 
        pares = upper.index[upper[col] >= umbral].tolist()

        for par in pares:
            # Comparar correlación promedio con el resto

            # corr[col].drop(col) toma todas las correlaciones de
            # la columna 'col' y elimina la correlación consigo misma.
            #Luego, calcula el promedio
            mean_col = corr[col].drop(col).mean() #columna 
            mean_par = corr[par].drop(par).mean() #par

            # Eliminar la que tiene mayor correlación promedio
            cols_eliminar.add(col if mean_col >= mean_par else par)

    # se hace una lista con todas aquellas uq eno están en "cols_eliminar"
    cols_conservar = [c for c in df_num.columns if c not in cols_eliminar]

    #retornar una lista con las que se van a conservar y las que se van a eliminar
    return cols_conservar, list(cols_eliminar)


UMBRAL_CORR = 0.80
conservar, eliminar = eliminar_correlacionadas(X_features, umbral=UMBRAL_CORR)

print(f'Umbral de correlación: {UMBRAL_CORR}')
print(f'Columnas eliminadas : {eliminar}')
print(f'Columnas conservadas: {conservar}')
# Out:
# Umbral de correlación: 0.8
# Columnas eliminadas : ['petal length (cm)', 'petal width (cm)']
# Columnas conservadas: ['sepal length (cm)', 'sepal width (cm)']

# %%
# Mostrar todos los pares con alta correlación
corr_abs = X_features.corr().abs()

#acá simplemente nos quedamos con el triángulo superior de la matriz de correlación, para no repetir pares
upper = corr_abs.where(np.triu(np.ones(corr_abs.shape), k=1).astype(bool))

#todo lo ponemos en paréntisis porque en python un salto de línea
#es el fin de una instrucción, entonces poner el paréntesis nos 
# soluciona esto.  
pares_altos = (
    upper.stack()
    .reset_index()
    .rename(columns={'level_0': 'Variable 1', 'level_1': 'Variable 2', 0: 'Correlación'})
    .query('Correlación >= @UMBRAL_CORR')
    .sort_values('Correlación', ascending=False)
    .reset_index(drop=True)
)

print(f'Pares con |correlación| ≥ {UMBRAL_CORR}:')
pares_altos.round(3)
# Out:
# Pares con |correlación| ≥ 0.8:
#           Variable 1         Variable 2  Correlación
# 0  petal length (cm)   petal width (cm)        0.963
# 1  sepal length (cm)  petal length (cm)        0.872
# 2  sepal length (cm)   petal width (cm)        0.818

# %%
prueba.stack() # Convierte el DataFrame en una Serie, eliminando los NaN y dejando solo los pares de correlación que cumplen la condición.
prueba.stack().reset_index() # Convierte la Serie en un DataFrame, con columnas 'level_0', 'level_1' y 0 (correlación)
prueba2 = prueba.stack().reset_index().rename(columns={'level_0': 'Variable 1', 'level_1': 'Variable 2', 0: 'Correlación'}) #renombrar
prueba2.query('Correlación >= @UMBRAL_CORR').sort_values('Correlación', ascending=False).reset_index(drop=True)#filtrar el data fame respecto a la VARIABLE DE ENTORNO
# UMBRAL_CORR y ordenarlo por medio de la correlación de manera descendente. y finalmente se quitan los índices viejos
# Out:
#           Variable 1         Variable 2  Correlación
# 0  petal length (cm)   petal width (cm)     0.962865
# 1  sepal length (cm)  petal length (cm)     0.871754
# 2  sepal length (cm)   petal width (cm)     0.817941

# %% [markdown]
# ### 3.4 Variables importantes con Random Forest
#
# **Concepto:** un Random Forest mide la importancia de cada variable como la **reducción promedio de impureza** (Mean Decrease in Impurity / índice Gini) que aporta esa variable a lo largo de todos los árboles del bosque.
#
# Las variables con importancia baja son candidatas a ser eliminadas sin afectar significativamente el rendimiento del modelo.
#
# **Recuerda:**
# - Cada árbol se entrena con una muestra *bootstrap* (muestreo con reemplazo).
# - En cada nodo se elige un subconjunto aleatorio de features, lo que reduce la correlación entre árboles.
# - La predicción final es la clase con más votos (clasificación) o el promedio (regresión).

# %%
X_iris = df[iris.feature_names] # seleccionar variables independientes
y_iris = df['species'] # seleccionar variable dependiente u objetivo

# Entrenar Random Forest
# instancia de la clase RandomForestClassifier (arquitectura orientada a objetos)
rf = RandomForestClassifier(n_estimators=200, random_state=42)
rf.fit(X_iris, y_iris) #ajustar el modelo

# Tabla de importancias. Se crea un data frame para su presentación
importancias = pd.DataFrame({
    'Feature': iris.feature_names, # atributo
    'Importancia': rf.feature_importances_ # atributo después de usar el métod .fit()
    #por eso usa el "_" al final. 
}).sort_values('Importancia', ascending=False).reset_index(drop=True)

print('Importancia de variables (Mean Decrease in Impurity):')
print('varibles con importancia baja, candidatas a ser eliminadas')
importancias.round(4)
# Out:
# Importancia de variables (Mean Decrease in Impurity):
# varibles con importancia baja, candidatas a ser eliminadas
#              Feature  Importancia
# 0  petal length (cm)       0.4593
# 1   petal width (cm)       0.4179
# 2  sepal length (cm)       0.1020
# 3   sepal width (cm)       0.0209

# %%
# Visualización

#1 solo espacio de figuras de 7 x 4
fig, ax = plt.subplots(figsize=(7, 4))

# un gráfico de barras donde los datos son el data frame creado 
# en el anterior comando, eje X importancia, eje Y variables
# de azul. 
sns.barplot(
    data=importancias, x='Importancia', y='Feature',
    palette='Blues_d', ax=ax
)

ax.set_title('Importancia de Variables — Random Forest')
ax.set_xlabel('Importancia (Mean Decrease in Impurity)')
ax.set_ylabel('varibles')
plt.tight_layout() #ajustar texto
plt.show()
# Out:
# /tmp/ipykernel_14996/4177293460.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
# Seleccionar variables con importancia >= umbral
UMBRAL_IMP = 0.05
#ojo el @ solo se usa con el método .query para hacer referencia a variables globales. 
vars_seleccionadas = importancias.query('Importancia >= @UMBRAL_IMP')['Feature'].tolist()
vars_seleccionadas_loc = importancias.loc[importancias["Importancia"]>= UMBRAL_IMP, "Feature"].tolist()
print(f'\nVariables seleccionadas (importancia ≥ {UMBRAL_IMP}): {vars_seleccionadas}')
print(f'\nVariables seleccionadas (importancia ≥ {UMBRAL_IMP}): {vars_seleccionadas_loc}')
# Out:
# Variables seleccionadas (importancia ≥ 0.05): ['petal length (cm)', 'petal width (cm)', 'sepal length (cm)']
#
# Variables seleccionadas (importancia ≥ 0.05): ['petal length (cm)', 'petal width (cm)', 'sepal length (cm)']

# %% [markdown]
# Notese que deacuerdo a la importancia de variables entonces el modelo puede predecri bastante bien la variable respuesta solo con las dimensiones del pétalo, ya que no hay mucha importancia en las medidas del sépalo

# %% [markdown]
# ### 3.5 Análisis de Componentes Principales (PCA)
#
# **Concepto:** PCA es una técnica de **transformación** (no de selección) que proyecta los datos originales en un nuevo espacio de menor dimensión, capturando la mayor cantidad posible de varianza.
#
# **Pasos:**
# 1. **Estandarizar** los datos (media 0, desviación 1) — PCA es sensible a la escala.
# 2. Calcular la **matriz de covarianza**.
# 3. Obtener los **valores propios** (cuánta varianza explica cada dirección) y los **vectores propios** (dirección de cada componente).
# 4. Ordenar componentes de mayor a menor varianza explicada.
# 5. **Proyectar** los datos sobre los primeros `k` componentes.
#
# Las componentes principales **no son interpretables** como las variables originales, pero permiten visualizar y comprimir los datos.
#
# Por tanto, si o si es importante reducir las dimsiones, de lo contarior pues mejor quedarse con las variables originales.
#
# > ⚠️ PCA solo aplica a variables numéricas.

# %%
# --- Paso 1: Estandarizar ---
scaler_z = StandardScaler() #instancia para el estandarizador
X_scaled = scaler_z.fit_transform(X_iris) #datos estandarizados 
#con el método .fil_transform(datos)

# --- Paso 2 y 3: PCA con todas las componentes ---
pca_full = PCA() #instancia del PCA para todos los componentes
pca_full.fit(X_scaled) # método para  aplicar el PCA a los datos Estandarizados

# varianza explicada como atributo luego de ajustar la instancia
varianza_explicada = pca_full.explained_variance_ratio_

#varianza acumulada
# np.cumsum retorna un vector con los valores sumados, acumulados
# hasta el i-ésimo elemento. 
varianza_acumulada = np.cumsum(varianza_explicada)


# Tabla de varianza explicada
pca_table = pd.DataFrame({
    'Componente': [f'PC{i+1}' for i in range(len(varianza_explicada))],
    'Varianza Explicada (%)': (varianza_explicada * 100).round(2),
    'Varianza Acumulada (%)': (varianza_acumulada * 100).round(2)
})
print(pca_table.to_string(index=False))
# Out:
# Componente  Varianza Explicada (%)  Varianza Acumulada (%)
#        PC1                   72.96                   72.96
#        PC2                   22.85                   95.81
#        PC3                    3.67                   99.48
#        PC4                    0.52                  100.00

# %%
print(varianza_explicada)
print(varianza_acumulada)
# Out:
# [0.72962445 0.22850762 0.03668922 0.00517871]
# [0.72962445 0.95813207 0.99482129 1.        ]

# %%
# --- Gráfica Scree Plot ---
#1 fila 2 columnas, de 12 x 4 cada figura
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

# Varianza individual
axes[0].bar(
    pca_table['Componente'], pca_table['Varianza Explicada (%)'],
    color='steelblue', edgecolor='white'
)
axes[0].set_title('Varianza Explicada por Componente')
axes[0].set_ylabel('%')

# Varianza acumulada
axes[1].plot(
    pca_table['Componente'], pca_table['Varianza Acumulada (%)'],
    marker='o', color='coral', linewidth=2
)
axes[1].axhline(95, color='red', linestyle='--', label='95 %')
axes[1].set_title('Varianza Acumulada')
axes[1].set_ylabel('%')
axes[1].legend()

plt.suptitle('Scree Plot — PCA sobre Iris', fontsize=13)
plt.tight_layout()
plt.show()

print('\n📌 Con 2 componentes se explica el', round(varianza_acumulada[1]*100, 1), '% de la varianza.')
# Out:
# 📌 Con 2 componentes se explica el 95.8 % de la varianza.

# %%
# --- Proyección en 2D (PC1 vs PC2) ---
pca_2d = PCA(n_components=2) # instancia para solo 2 componentes

X_pca = pca_2d.fit_transform(X_scaled) # ajuste, que viene a ser 
#los 150 datos proyectados en mi nuevo espacio de 2 dimensiones.
# se retorna en un arreglo de numpy 

#lo volvemos un data frame y le ponemos los nombre
pca_df = pd.DataFrame(X_pca, columns=['PC1', 'PC2'])

#agregamos la varible respuesta. 
pca_df['species'] = df['species_name'].values

#un solo gráfico de 7x5
fig, ax = plt.subplots(figsize=(7, 5))


#se agrupa el data frame por cda clase de planta y 
#se hace un diagrama de dispersión con un color distinto por especie
# donde s = 50 es el tamaño de los puntos y 0.8 la transparencia.
for especie, grupo in pca_df.groupby('species'):
    ax.scatter(grupo['PC1'], grupo['PC2'], label=especie, s=50, alpha=0.8)

# Añadir vectores de carga (loadings)
loadings = pca_2d.components_.T #vectores de dirección de las 4 variables
#originales para ver su calidad y representación respecto a los ejes
#principales nuevos.

#pca_2d.components_ : tiene las coordenadas que definen los componentes y al 
#transponerlo con .T, se obtiene una matriz donde cada fila represetna una de 
#las varaibles originales
 
scale = 3 # factor de escala para que las flechas sean más grandes. 
for i, feat in enumerate(iris.feature_names):

    #flecha del origen hasta el vector de carga de la i-ésima 
    #variable. 
    ax.annotate(
        '', xy=(loadings[i, 0] * scale, loadings[i, 1] * scale),
        xytext=(0, 0),
        arrowprops=dict(arrowstyle='->', color='black', lw=1.5)
    )

    #escribe el nombre de la variable al extremos de la flecha. 
    #centrádo y quitándole la palabbra (cm)
    ax.text(
        loadings[i, 0] * scale * 1.15,
        loadings[i, 1] * scale * 1.15,
        feat.replace(' (cm)', ''), fontsize=8, ha='center'
    )

#nombre eje x
ax.set_xlabel(f'PC1 ({varianza_explicada[0]*100:.1f} % var. explicada)')

#nombre eje y
ax.set_ylabel(f'PC2 ({varianza_explicada[1]*100:.1f} % var. explicada)')

#nombre título principal
ax.set_title('Biplot PCA — 2 Componentes')

#titulo de la leyenda
ax.legend(title='Especie')

#organizar texto
plt.tight_layout()

#generar imagen. 
plt.show()

# %% [markdown]
# Nota: repasar con estadística multivariada la parte matemática de las componentes principales y su interpretación en los gráficos.

# %%
X_pca.shape # cada dato proyectado en las nuevas dimensiones
# Out:
# (150, 2)

# %%
pca_df.head()
# Out:
#         PC1       PC2 species
# 0 -2.264703  0.480027  setosa
# 1 -2.080961 -0.674134  setosa
# 2 -2.364229 -0.341908  setosa
# 3 -2.299384 -0.597395  setosa
# 4 -2.389842  0.646835  setosa

# %%
for especie, grupo in pca_df.groupby('species'):
    #se agrupa por especie y grupo[PC1] son todas las coordenadas
    #del PC1 y el grupo[PC2] pues directamente del PC2. 
    ax.scatter(grupo['PC1'], grupo['PC2'], label=especie, s=50, alpha=0.8)

# %%
#print(df.columns[:4].tolist())
pca_2d.components_ # tiene las coordenadas que definen a los componentes
#pca_2d.components_.T # matriz donde cada fila es una de las variable orignales 
#proyectadas en el nuevo espacio vectorial. 

#estos son los vectores propios de cada una de las componentes. y pues
#aparecen en orden con respecto al orden de las columnas. 

df_m = pd.DataFrame(
    pca_2d.components_,
    columns= df.columns[:4].tolist()
)
print(df_m)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0           0.521066         -0.269347           0.580413          0.564857
# 1           0.377418          0.923296           0.024492          0.066942

# %%
# --- Tabla de loadings (contribución de cada variable a cada PC) ---
loadings_df = pd.DataFrame(
    pca_2d.components_.T, # al transponerlas los nombres de las columnas
    #deben pasar a ser los índices. 
    index=iris.feature_names, #ponemos de índice el nombre de las varibles
    columns=['PC1', 'PC2'] # nombre de las columnas
).round(3)
print('Loadings (contribución de cada variable a cada componente):')
loadings_df
# Out:
# Loadings (contribución de cada variable a cada componente):
#                      PC1    PC2
# sepal length (cm)  0.521  0.377
# sepal width (cm)  -0.269  0.923
# petal length (cm)  0.580  0.024
# petal width (cm)   0.565  0.067

# %% [markdown]
# --- sigue clase del 14 de mayo.
# ## 4. Ingeniería de Características
#
# La **Ingeniería de Características** (Feature Engineering) mejora el rendimiento del modelado transformando el espacio de variables.  Incluye:
# - **Normalización**: escalar variables a un rango común.
# - **Discretización**: convertir variables continuas en categorías.
# - **Recodificación**: convertir variables categóricas en numéricas.
#
# por ejemplo, hay algunos algoritmos que son basados en distancias como el KNN o el Clustering donde la escala puede sesgar los resultados, por tanto, es necesario normalizar los datos.

# %% [markdown]
# ### 4.1 Normalización
#
# La normalización escala los valores numéricos para hacerlos comparables entre sí. Es especialmente importante en algoritmos basados en distancias (KNN, clustering) y en gradiente descendente.
#
# Sirve para eliminar posibles distorsiones de los algoritmos por confundirse en las escalas.
#
# Nota: Estas transformaciónes NO cambian la distribución, solo cambian la escala. Para que todo sea más fácil.
#
# Si hay tranformaciones que cambién la distribución pero se usan mayormente cuando se usan algoritmos o métodos que requiren supuestos como la regresión lineal.
#
# #### Algunos Métodos (hay más):
#
# | Método | Fórmula | Rango resultante | Sensible a outliers |
# |--------|---------|-----------------|---------------------|
# | **Min-Max** | $X^* = \dfrac{X - \min(X)}{\max(X) - \min(X)}$ | [0, 1] | Sí |
# | **Z-Score** | $Z = \dfrac{X - \mu}{\sigma}$ | Sin límite (≈ -3 a 3) | Moderadamente |
# | **Decimal Scaling** | $X_d = \dfrac{X}{10^d}$ | (-1, 1) | No |
# | **Robusto (IQR)** | $X_r = \dfrac{X - Q_2}{Q_3 - Q_1}$ | Sin límite fijo | No |
#
# Donde $d$ es el número de dígitos del valor absoluto máximo.

# %%
# Tomamos 'sepal length (cm)' como ejemplo (igual que en las diapositivas)
col = 'sepal length (cm)'
X_col = df[[col]].copy() # copía de un data frame de la varible sepal length 

# --- Min-Max ---
mm = MinMaxScaler() #instancia de la función minmax
df[col + '_minmax'] = mm.fit_transform(X_col) # acá se hace la transformación

# --- Z-Score ---
zs = StandardScaler() #instancia del z-score
df[col + '_zscore'] = zs.fit_transform(X_col) #ajuste.

# --- Decimal Scaling ---
max_abs = X_col[col].abs().max()# tomamos el máximo del valor absoluto de los datos. 
d = len(str(int(max_abs)))          # Número de dígitos de la parte entera del máximo
df[col + '_decimal'] = X_col[col] / (10 ** d) #cálculo de la transformación

# --- Robusto (mediana e IQR) ---
rs = RobustScaler() # instancia
df[col + '_robusto'] = rs.fit_transform(X_col) #ajuste

# Mostrar las primeras filas con todas las versiones
cols_norm = [col, col+'_minmax', col+'_zscore', col+'_decimal', col+'_robusto']
df[cols_norm].head(10).round(4)
# Out:
#    sepal length (cm)  sepal length (cm)_minmax  sepal length (cm)_zscore  \
# 0                5.1                    0.2222                   -0.9007
# 1                4.9                    0.1667                   -1.1430
# 2                4.7                    0.1111                   -1.3854
# 3                4.6                    0.0833                   -1.5065
# 4                5.0                    0.1944                   -1.0218
# 5                5.4                    0.3056                   -0.5372
# 6                4.6                    0.0833                   -1.5065
# 7                5.0                    0.1944                   -1.0218
# 8                4.4                    0.0278                   -1.7489
# 9                4.9                    0.1667                   -1.1430
#
#    sepal length (cm)_decimal  sepal length (cm)_robusto
# 0                       0.51                    -0.5385
# 1                       0.49                    -0.6923
# 2                       0.47                    -0.8462
# 3                       0.46                    -0.9231
# 4                       0.50                    -0.6154
# 5                       0.54                    -0.3077
# 6                       0.46                    -0.9231
# 7                       0.50                    -0.6154
# 8                       0.44                    -1.0769
# 9                       0.49                    -0.6923

# %%
# --- Visualización comparativa de distribuciones ---
titulos = ['Original', 'Min-Max', 'Z-Score', 'Decimal Scaling', 'Robusto (IQR)']
data_cols = cols_norm

fig, axes = plt.subplots(1, 5, figsize=(18, 4), sharey=False)
for ax, col_plot, titulo in zip(axes, data_cols, titulos):
    ax.hist(df[col_plot], bins=20, color='steelblue', edgecolor='white')
    ax.set_title(titulo, fontsize=10)

    # Calculamos min y max primero para que el código sea legible
    val_min = df[col_plot].min()
    val_max = df[col_plot].max()

    # Usamos f-strings para formatear a 2 decimales y convertir a texto automáticamente
    ax.set_xlabel(f"{val_min:.2f} … {val_max:.2f}", fontsize=8)

fig.suptitle(f'Distribución de "{col}" con diferentes normalizaciones', fontsize=12)
plt.tight_layout()
plt.show()

print('\n📌 Nota: la FORMA de la distribución no cambia, solo la escala. \n Los métodos que si cambian al distribución de los datos es para \n los casos que se necestia que se cumplan supuestos. ')
# Out:
# 📌 Nota: la FORMA de la distribución no cambia, solo la escala.
#  Los métodos que si cambian al distribución de los datos es para
#  los casos que se necestia que se cumplan supuestos.

# %%
# Estadísticas descriptivas de cada versión normalizada
df[cols_norm].describe().round(4)
# Out:
#        sepal length (cm)  sepal length (cm)_minmax  sepal length (cm)_zscore  \
# count           150.0000                  150.0000                  150.0000
# mean              5.8433                    0.4287                   -0.0000
# std               0.8281                    0.2300                    1.0034
# min               4.3000                    0.0000                   -1.8700
# 25%               5.1000                    0.2222                   -0.9007
# 50%               5.8000                    0.4167                   -0.0525
# 75%               6.4000                    0.5833                    0.6745
# max               7.9000                    1.0000                    2.4920
#
#        sepal length (cm)_decimal  sepal length (cm)_robusto
# count                   150.0000                   150.0000
# mean                      0.5843                     0.0333
# std                       0.0828                     0.6370
# min                       0.4300                    -1.1538
# 25%                       0.5100                    -0.5385
# 50%                       0.5800                     0.0000
# 75%                       0.6400                     0.4615
# max                       0.7900                     1.6154

# %% [markdown]
# ### 4.2 Discretización — Binning
#
# **Concepto:** la discretización convierte una variable continua en categorías o intervalos. Esto:
# - Simplifica la representación de los datos.
# - Puede ayudar a ciertos algoritmos que trabajan mejor con variables categóricas.
# - Reduce el efecto de los outliers.
#
# **La discretización se usa para buscar relación entre variables que no es clara en  su forma continua. Muy útil para problemas de clasificación pues se puede segmentar las variables y puede ser más sencillo ver relaciones entre grupos. Por ejemplo, muchas veces es más sencillo ver relaciones con grupos de edad.**
#
# **Todo se basa en un método iterativo, habrán ocasiones que discretizar sea lo mejor y en otras ocasiones no, por ello, es necesario abarcar todas las posibles opciones y luego revisar métricas de desempeño para hacer la mejor elección**
#
# **Es importante no quedarse simplemente con el primer modelo, es importante revisar distintos modelos con diferentes técnicas y diferentes algoritmos**
#
# #### Tipos de Binning (no supervisado):
# - **Igual Ancho (Equal Width):** divide el rango en `k` intervalos del mismo tamaño.
#   → Sencillo, pero puede dejar bins vacíos si hay outliers.
# - **Igual Frecuencia (Equal Frequency / Quantiles):** cada bin contiene el mismo número de observaciones.
#   → Mejor distribución de datos, respeta la densidad.
#
# Trabajaremos con `petal length (cm)` dividida en 3 categorías.

# %%
col_disc = 'petal length (cm)' # selección de la columna

#selección del número de categorías para la discretizacón
K = 3  # Número de bins
labels_bins = ['Bajo', 'Medio', 'Alto'] #categorías
#acá es donde hay que tener una razón adecuada para justificar el 3, tal 
# vez por ejemplo porque es la mejor forma de identificar pétalos
# o porque son los únicos tamaños de pétalo, etc. Hay que 
# referenciarse bien. 


# --- Igual Ancho ---
# Creación de instancia del objeto para discretizar, notese que se da
# el número de categorías, el encode='ordinal' indica que devuelva los grupos
# como números enteros ordenados (0, 1 y 2), strategy='uniform' Defíne 
# que los límites de los intervalos sean de igual ancho, es decir, máximo - mínimio
#divido el número de categorías. 
kbd_ancho = KBinsDiscretizer(n_bins=K, encode='ordinal', strategy='uniform')

# creación de una variable, que sea la variable petal_lenght()
# y se ajusta el método de discretización, notese que la columna se pone
#en 2 corchetes porque el argumento debe ser un data_frame
# y al final los volvemos valores enteros
df['petal_length_igulancho'] = kbd_ancho.fit_transform(df[[col_disc]]).astype(int)

#a continuación creamos otra variable pasando los valores a categorías
# pero ya las categorías como cadenas para entendimiento humano. 
df['petal_length_igulancho_lbl'] = df['petal_length_igulancho'].map(
    {0: 'Bajo', 1: 'Medio', 2: 'Alto'}
)

edges_ancho = kbd_ancho.bin_edges_[0].round(3) # obtener una lista
# de los límites o bordes de los intervalos redondeando a 3 decimales
print(f'Igual Ancho — Bordes de bins: {edges_ancho}') # imprime la lista de los puntos de corte calculados

#agrupar por las categorías de la discretización, seleccionar solo la variable original
#que es continua y hallar el valor mínimo, máximo y pues número de elementos por cada una
#de las categorías. 
print(df.groupby('petal_length_igulancho_lbl')[col_disc].agg(['min','max','count']))

print()

# --- Igual Frecuencia --- (útil para variables con sesgos)
# Creación de instancia del objeto para discretizar, notese que se da
# el número de categorías, el encode='ordinal' indica que devuelva los grupos
# como números enteros ordenados (0, 1 y 2), strategy='quantile' Defíne 
# que los límites de los intervalos sean de igual frecuencia usando los cuantiles
kbd_freq = KBinsDiscretizer(n_bins=K, encode='ordinal', strategy='quantile')

#creación de la variable y convertir los número en enteros
df['petal_length_igualfreq'] = kbd_freq.fit_transform(df[[col_disc]]).astype(int)

#mapearlos a cadenas
df['petal_length_igualfreq_lbl'] = df['petal_length_igualfreq'].map(
    {0: 'Bajo', 1: 'Medio', 2: 'Alto'}
)

#obtener límites de los intervalos
edges_freq = kbd_freq.bin_edges_[0].round(3)

print(f'Igual Frecuencia — Bordes de bins: {edges_freq}')
print(df.groupby('petal_length_igualfreq_lbl')[col_disc].agg(['min','max','count']))
# Out:
# Igual Ancho — Bordes de bins: [1.    2.967 4.933 6.9  ]
#                             min  max  count
# petal_length_igulancho_lbl
# Alto                        5.0  6.9     46
# Bajo                        1.0  1.9     50
# Medio                       3.0  4.9     54
#
# Igual Frecuencia — Bordes de bins: [1.  3.  4.9 6.9]
#                             min  max  count
# petal_length_igualfreq_lbl
# Alto                        4.9  6.9     51
# Bajo                        1.0  1.9     50
# Medio                       3.0  4.8     49

# %%
#recordemos que kbd_ancho es la instancia del método de discretización
#por intervalos de igual anchura y bin_edges_ es un atributo luego 
#de ajustar con los límites de los 3 intervalos
kbd_ancho.bin_edges_
# Out:
# array([array([1.        , 2.96666667, 4.93333333, 6.9       ])],
#       dtype=object)

# %%
#este código cuenta la cantidad de elementos por intervalo(categoría nueva)
df['petal_length_igulancho_lbl'].value_counts()

#acá damos un orden específico
df['petal_length_igulancho_lbl'].value_counts().reindex(labels_bins)
#.reindex() reordena el índice de la serie devuelta por value_counts() para 
#que coincida exactamente con la lista labels_bins = ['Bajo', 'Medio', 'Alto']

item =df['petal_length_igulancho_lbl'].value_counts().reindex(labels_bins).items
type(item) #método
item
# Out:
# <bound method Series.items of petal_length_igulancho_lbl
# Bajo     50
# Medio    54
# Alto     46
# Name: count, dtype: int64>

# %%
# Visualización comparativa de los dos métodos de binning
#figura de 1 fila por 3 columnas, cada una de 15x4 pixelex
fig, axes = plt.subplots(1, 3, figsize=(15, 4))
#diccionario de colores
colores = {'Bajo': '#2196F3', 'Medio': '#4CAF50', 'Alto': '#FF5722'}

# Original
#Realizar un histograma de la variable col_disc, con 20 particiones
#de color gris y rodeado de blanco
axes[0].hist(df[col_disc], bins=20, color='gray', edgecolor='white')
axes[0].set_title('Distribución Original') #título
axes[0].set_xlabel(col_disc)#eje X

# Igual Ancho — barras de conteo por bin
conteo_ancho = df['petal_length_igulancho_lbl'].value_counts().reindex(labels_bins)

#gráfico de barras, donde el eje X es las categorías que son los índices
#el eje Y son los los valores. 
axes[1].bar(conteo_ancho.index, conteo_ancho.values,
            color=[colores[l] for l in conteo_ancho.index], edgecolor='white')

#le ponemos el texto a cada gráfica
# ix es para los número del numerate y el (lbl,cnt) es
#por que conteo_ancho.items() retorna algo así: categoría - cantidad
#entonces por eso pasa
for ix, (lbl, cnt) in enumerate(conteo_ancho.items()):
    axes[1].text(ix, cnt + 1, str(cnt), ha='center', fontsize=10)

axes[1].set_title(f'Igual Ancho (k={K})') #título 

axes[1].set_ylabel('# Observaciones') #título eje y

# Igual Frecuencia
#igualmente estamos sacando valores por categoría
conteo_freq = df['petal_length_igualfreq_lbl'].value_counts().reindex(labels_bins)
#se crea el gráfico de barras.
axes[2].bar(conteo_freq.index, conteo_freq.values,
            color=[colores[l] for l in conteo_freq.index], edgecolor='white')
#se ponen los títulos
for ix, (lbl, cnt) in enumerate(conteo_freq.items()):
    axes[2].text(ix, cnt + 1, str(cnt), ha='center', fontsize=10)
axes[2].set_title(f'Igual Frecuencia (k={K})') #título

fig.suptitle(f'Discretización de "{col_disc}"', fontsize=12) #título superior
plt.tight_layout() #organizr texto
plt.show() #mostrar

# %% [markdown]
# En la práctica siempre estamos sujetos a tomar decisiones y estas deben estar bien respaldadas en la académia. Así sea que sea un método supervisado o no supervisado, por ejemplo, dividir las edades en intervalos de 5 años, ¿por qué? y ¿por qué no de a otro número?, es necesario justificar cada decisión.
#
# El tamaño de los intervalos o la cantidad de intervalos debe tener una razón clara y con buenos argumentos pues no debe hacerse nada sin las razones adecuadas. Es importante justificar todo, no necesariamente con una base teórica pero almenos si práctica, según el contexto del proyecto.
#
# El tomar decisiones para los datos y con los datos puede tener consecuencias importantes en el proyecto, por ello, no se puede tomar nada a la ligera sino ser consciente de todo lo que se haga por más tribial que aparente ser. Todo para que en caso de una auditoría o revisión del trabajo todo este argumentado de una manera exacta y precisa y que no haya ningún problema, que todo es una decisión robusta y no inventada.

# %% [markdown]
# ### 4.3 Discretización basada en Entropía (Supervisada)
#
# **Concepto:** en lugar de dividir según el rango o la frecuencia, este método busca los puntos de corte que **maximizan la ganancia de información** con respecto a la variable objetivo. Es un método **supervisado**. LA ENTROPÍA PRINCIPALMENTE SE USA CUANDO LA VARIBLE RESPUESTA ES BINARIA, ES DECIR, SOLO 2 OPCIONES.
#
# **Fórmulas clave:**
#
# $$H(Y) = -\sum_{i=1}^{k} p(C_i) \log_2 p(C_i) \quad \text{(entropía de la clase)}$$
#
# $$H(Y|X, t) = P(X \leq t) \cdot H(Y|X \leq t) + P(X > t) \cdot H(Y|X > t) \quad \text{(entropía tras el corte)}$$
#
# $$\text{IG} = H(Y) - H(Y|X, t) \quad \text{(ganancia de información)}$$
#
# El **mejor punto de corte** es el que maximiza IG (o equivalentemente, minimiza $H(Y|X, t)$).
#
# #### Opción A: implementación manual del mejor split

# %% [markdown]
# min 37

# %%
#código manual para hallar puntos óptimos que usa un árbol de decisión
#se buscan los puntos exactos de X para cortar los datos y separa de la 
#mejor manera posible las clases de y.
def entropia(y):
    """Calcula la entropía de Shannon de un arreglo de etiquetas."""
    if len(y) == 0:
        return 0
    counts = np.bincount(y) # cuenta la cantidad de veces que aparece cada clase en
    #el arreglo de enteros 'y'
    probs = counts[counts > 0] / len(y) #filtrar las clases con frecuencia 0 porque
    #log_2(0) es una indetermtinación y el len(Y) es para hacerlo probabilidad
    return -np.sum(probs * np.log2(probs)) #aplica la fórmula exacta de shanon
    #H(Y)

#evaluar todos los posibles puntos medios entre valores consecutivos para encontrar
#el corte perfecto.
def mejor_split(X_vals, y_vals):
    """
    Encuentra el punto de corte que maximiza la ganancia de información
    para una variable continua X respecto de la variable objetivo y.

    Retorna:
        mejor_t : el valor del punto de corte óptimo
        mejor_ig: la ganancia de información en ese punto
        tabla   : DataFrame con IG para todos los puntos evaluados
    """
    orden = np.argsort(X_vals) #retorna los índices de como deberían
    #ser ordenadas los valores de la variable,,,
    X_sorted = X_vals[orden] #seleccionamos los valores ordenados
    y_sorted = y_vals[orden] #seleccionamos los valores de Y según 
    #el orden de los de X_vals
    n = len(X_sorted) #número de valores de la variable
    H_total = entropia(y_sorted) #calcular la entropía total de todo 
    #el conjunto

    resultados = []
    for i in range(1, n):
        # Solo evaluar entre valores distintos
        if X_sorted[i] == X_sorted[i - 1]:
            continue
        #evaluamos todos los puntos medios  posbiles
        t = (X_sorted[i] + X_sorted[i - 1]) / 2  # Punto medio

        #entropías condicionales
        H_izq = entropia(y_sorted[:i]) #ENTROPÍA CONDICIONAL IZQUIERDA
        H_der = entropia(y_sorted[i:]) #ENTROPÍA CONDICIONAL DERECHA

        #cálculo de la entropía luego de la discretización
        H_cond = (i / n) * H_izq + ((n - i) / n) * H_der 

        #Entropía total - condicionada por el i-ésimo punto
        IG = H_total - H_cond# A menor incertidumbre, mayor ganancia
        #de información IG, porque H_cond sería pequeña.

        #Agregamos los resultados a la lista
        resultados.append({'t': round(t, 4),
                            'H_izq': round(H_izq, 4),
                            'H_der': round(H_der, 4),
                            'H_cond': round(H_cond, 4),
                            'IG': round(IG, 4)})

    tabla = pd.DataFrame(resultados) #se crea un data frame
    idx_mejor = tabla['IG'].idxmax() #encuentra el índice de la fila donde
    #la ganancia de la información alcanzó su valor máximo.
    mejor_t = tabla.loc[idx_mejor, 't'] #de ese índice, traer la columna t(punto medio)
    mejor_ig = tabla.loc[idx_mejor, 'IG'] # y la columna id
    return mejor_t, mejor_ig, tabla


# Aplicar a 'petal length (cm)'
X_vals = df['petal length (cm)'].values #valores variable petal lenght
y_vals = df['species'].values #valores especies

#cálculamos la entropía
mejor_t, mejor_ig, tabla_splits = mejor_split(X_vals, y_vals)
H_clase = entropia(y_vals)

print(f'Entropía inicial de la clase: {H_clase:.4f}')
print(f'\n✅ Mejor punto de corte: {mejor_t} cm  →  Ganancia de Información = {mejor_ig:.4f}')
print()
print('Top 5 puntos de corte con mayor Ganancia de Información:')
tabla_splits.nlargest(5, 'IG')
# Out:
# Entropía inicial de la clase: 1.5850
#
# ✅ Mejor punto de corte: 2.45 cm  →  Ganancia de Información = 0.9183
#
# Top 5 puntos de corte con mayor Ganancia de Información:
#        t   H_izq   H_der  H_cond      IG
# 8   2.45 -0.0000  1.0000  0.6667  0.9183
# 9   3.15  0.1392  0.9999  0.7073  0.8777
# 10  3.40  0.3138  0.9993  0.7571  0.8279
# 7   1.80 -0.0000  1.1196  0.7613  0.8236
# 11  3.55  0.4395  0.9980  0.7932  0.7917

# %% [markdown]
# Notese que todos son valores altos, pero el punto que maximiza este índice IG es el que minimiza la entropía de condicinoal discretizada y es el punto 2.45

# %%
# Visualizar la Ganancia de Información en función del punto de corte
#figura de 9 x 4
fig, ax = plt.subplots(figsize=(9, 4))
#gráfico de los puntos en el eje X, y el índice IG en el eje Y, de color azul y ancho de línea 1.5
ax.plot(tabla_splits['t'], tabla_splits['IG'], color='steelblue', linewidth=1.5)
ax.axvline(mejor_t, color='red', linestyle='--', label=f'Mejor corte: {mejor_t} cm')
ax.set_xlabel('Punto de Corte t (cm)')
ax.set_ylabel('Ganancia de Información (IG)')
ax.set_title(f'IG vs. Punto de Corte — "{col_disc}"')
ax.legend()
plt.tight_layout()
plt.show()

# %%
# Discretizar con el mejor punto de corte encontrado
# discretizando con solo 2 categorías con corto y largo
df['petal_length_entropia'] = np.where(
    df['petal length (cm)'] <= mejor_t, 'Corto', 'Largo'
)

# Tabla de contingencia con la variable objetivo
#hacer una tabla cruzada, petal_length_entropia
#de fila y species_name de columnas
tabla_cont = pd.crosstab(
    df['petal_length_entropia'], df['species_name'],
    margins=True
)
print(f'Distribución con corte en {mejor_t} cm:')
tabla_cont
# Out:
# Distribución con corte en 2.45 cm:
# species_name           setosa  versicolor  virginica  All
# petal_length_entropia
# Corto                      50           0          0   50
# Largo                       0          50         50  100
# All                        50          50         50  150

# %% [markdown]
# Por tanto, es claro que el punto óptimo se escoge fácilmente gracias a la entropía y el índice IG, sin embargo, la categorización solo puede llevarse a cabo con 2 categorías; los valores menores y mayores al punto crítico de corte hallado.

# %% [markdown]
# min 40

# %% [markdown]
# #### Opción B: Discretización con árbol de decisión (múltiples cortes)
#
# Podemos automatizar la búsqueda de múltiples puntos de corte entrenando un `DecisionTreeClassifier` sobre la variable a discretizar. Los umbrales del árbol son los puntos de corte óptimos.

# %%
# Entrenar árbol de decisión para encontrar múltiples cortes
arbol = DecisionTreeClassifier(
    criterion='entropy',
    max_leaf_nodes=4,   # = número máximo de bins
    random_state=42
)
arbol.fit(df[['petal length (cm)']], df['species'])

# Extraer puntos de corte (se filtran los -2 que son nodos hoja)
cortes = np.sort(arbol.tree_.threshold[arbol.tree_.threshold != -2])
print(f'Puntos de corte encontrados por el árbol: {cortes.round(3)}')

# Crear bins con esos cortes
bins_tree = np.concatenate(([-np.inf], cortes, [np.inf]))
labels_tree = [f'bin_{i+1}' for i in range(len(bins_tree) - 1)]

df['petal_length_arbol'] = pd.cut(
    df['petal length (cm)'],
    bins=bins_tree,
    labels=labels_tree,
    include_lowest=True
)

print()
print('Conteo por bin:')
print(df.groupby('petal_length_arbol')['petal length (cm)'].agg(['min', 'max', 'count']))
# Out:
# Puntos de corte encontrados por el árbol: [2.45 4.75 5.15]
#
# Conteo por bin:
#                     min  max  count
# petal_length_arbol
# bin_1               1.0  1.9     50
# bin_2               3.0  4.7     45
# bin_3               4.8  5.1     21
# bin_4               5.2  6.9     34
# /tmp/ipykernel_4301/1974465798.py:26: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   print(df.groupby('petal_length_arbol')['petal length (cm)'].agg(['min', 'max', 'count']))

# %%
# Visualizar la discretización del árbol sobre la distribución original
fig, ax = plt.subplots(figsize=(9, 4))
ax.hist(df['petal length (cm)'], bins=30, color='lightgray', edgecolor='white', label='Original')
for c in cortes:
    ax.axvline(c, color='red', linestyle='--', alpha=0.8)
# Anotar los cortes
for i, c in enumerate(cortes):
    ax.text(c + 0.05, ax.get_ylim()[1] * 0.9, f'{c:.2f}', color='red', fontsize=9)
ax.set_xlabel('petal length (cm)')
ax.set_ylabel('Frecuencia')
ax.set_title('Discretización basada en árbol de decisión (entropía)')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 4.4 Recodificación de Variables Categóricas — One-Hot Encoding
#
# **Concepto:** muchos algoritmos requieren que todas las variables sean numéricas. Para variables categóricas, se crea una columna binaria (0 o 1) por cada categoría posible, llamada **variable dummy** o **one-hot**.
#
# **Ejemplo:**
# `species = ['setosa', 'versicolor', 'virginica']` → tres columnas: `species_setosa`, `species_versicolor`, `species_virginica`.
#
# > ⚠️ En regresión lineal y logística se elimina **una** de las columnas (la categoría de referencia) para evitar multicolinealidad perfecta.

# %%
# Usaremos la variable 'species_name' (setosa, versicolor, virginica)
ohe = OneHotEncoder(sparse_output=False, dtype=int)
encoded = ohe.fit_transform(df[['species_name']])

# Crear DataFrame con las columnas dummies
nombres_cols = [f'species_{cat}' for cat in ohe.categories_[0]]
df_dummies = pd.DataFrame(encoded, columns=nombres_cols)

print('Primeras 10 filas con One-Hot Encoding:')
pd.concat([df[['species_name']], df_dummies], axis=1).head(10)
# Out:
# Primeras 10 filas con One-Hot Encoding:
#   species_name  species_setosa  species_versicolor  species_virginica
# 0       setosa               1                   0                  0
# 1       setosa               1                   0                  0
# 2       setosa               1                   0                  0
# 3       setosa               1                   0                  0
# 4       setosa               1                   0                  0
# 5       setosa               1                   0                  0
# 6       setosa               1                   0                  0
# 7       setosa               1                   0                  0
# 8       setosa               1                   0                  0
# 9       setosa               1                   0                  0

# %%
# Para regresión: eliminar una columna (la última) para evitar multicolinealidad
ohe_drop = OneHotEncoder(sparse_output=False, dtype=int, drop='first')
encoded_drop = ohe_drop.fit_transform(df[['species_name']])

nombres_drop = [f'species_{cat}' for cat in ohe_drop.categories_[0][1:]]
df_dummies_drop = pd.DataFrame(encoded_drop, columns=nombres_drop)

print('Con drop="first" (para regresión):')
pd.concat([df[['species_name']], df_dummies_drop], axis=1).head(10)
# Out:
# Con drop="first" (para regresión):
#   species_name  species_versicolor  species_virginica
# 0       setosa                   0                  0
# 1       setosa                   0                  0
# 2       setosa                   0                  0
# 3       setosa                   0                  0
# 4       setosa                   0                  0
# 5       setosa                   0                  0
# 6       setosa                   0                  0
# 7       setosa                   0                  0
# 8       setosa                   0                  0
# 9       setosa                   0                  0

# %% [markdown]
# ---
# ## 5. Resumen comparativo
#
# A continuación se muestra un resumen de todas las técnicas aplicadas en este notebook.

# %%
resumen = pd.DataFrame([
    {
        'Técnica': 'Eliminar columnas con nulos',
        'Categoría': 'Reducción de Dimensionalidad',
        'Tipo': 'No supervisada',
        'Ventaja': 'Elimina ruido cuando no es posible imputar',
        'Limitación': 'Pérdida de información si el umbral es muy agresivo'
    },
    {
        'Técnica': 'Low Variance Filter',
        'Categoría': 'Reducción de Dimensionalidad',
        'Tipo': 'No supervisada',
        'Ventaja': 'Sencillo y rápido',
        'Limitación': 'Solo aplica a variables numéricas; requiere normalizar'
    },
    {
        'Técnica': 'Eliminación de correlacionadas',
        'Categoría': 'Reducción de Dimensionalidad',
        'Tipo': 'No supervisada',
        'Ventaja': 'Elimina redundancia sin perder información',
        'Limitación': 'No captura relaciones no lineales'
    },
    {
        'Técnica': 'Random Forest VarImp',
        'Categoría': 'Reducción de Dimensionalidad',
        'Tipo': 'Supervisada',
        'Ventaja': 'Captura relaciones no lineales; robusto',
        'Limitación': 'Computacionalmente costoso; sesgado a variables con más categorías'
    },
    {
        'Técnica': 'PCA',
        'Categoría': 'Reducción de Dimensionalidad',
        'Tipo': 'No supervisada',
        'Ventaja': 'Reduce dimensiones manteniendo máxima varianza; útil para visualización',
        'Limitación': 'Componentes no interpretables; solo para variables numéricas'
    },
    {
        'Técnica': 'Normalización Min-Max',
        'Categoría': 'Ingeniería de Características',
        'Tipo': 'No supervisada',
        'Ventaja': 'Rango fijo [0, 1]; intuitivo',
        'Limitación': 'Muy sensible a outliers'
    },
    {
        'Técnica': 'Normalización Z-Score',
        'Categoría': 'Ingeniería de Características',
        'Tipo': 'No supervisada',
        'Ventaja': 'Estándar estadístico; amplamente usado',
        'Limitación': 'Asume distribución aproximadamente normal'
    },
    {
        'Técnica': 'Decimal Scaling',
        'Categoría': 'Ingeniería de Características',
        'Tipo': 'No supervisada',
        'Ventaja': 'Simple; mantiene la estructura decimal',
        'Limitación': 'El rango resultante depende del máximo absoluto'
    },
    {
        'Técnica': 'Escalado Robusto',
        'Categoría': 'Ingeniería de Características',
        'Tipo': 'No supervisada',
        'Ventaja': 'Resistente a outliers (usa mediana e IQR)',
        'Limitación': 'Sin rango fijo de salida'
    },
    {
        'Técnica': 'Binning Igual Ancho',
        'Categoría': 'Ingeniería de Características',
        'Tipo': 'No supervisada',
        'Ventaja': 'Fácil de interpretar',
        'Limitación': 'Bins desbalanceados si la distribución es sesgada'
    },
    {
        'Técnica': 'Binning Igual Frecuencia',
        'Categoría': 'Ingeniería de Características',
        'Tipo': 'No supervisada',
        'Ventaja': 'Bins balanceados',
        'Limitación': 'Bordes irregulares, menos intuitivos'
    },
    {
        'Técnica': 'Discretización por Entropía',
        'Categoría': 'Ingeniería de Características',
        'Tipo': 'Supervisada',
        'Ventaja': 'Usa información de la clase; óptimo para clasificación',
        'Limitación': 'Requiere variable objetivo; riesgo de sobreajuste'
    },
    {
        'Técnica': 'One-Hot Encoding',
        'Categoría': 'Ingeniería de Características',
        'Tipo': 'No supervisada',
        'Ventaja': 'Necesario para algoritmos numéricos',
        'Limitación': 'Aumenta la dimensionalidad con muchas categorías'
    },
    {
        'Técnica': 'Information Value (IV) / WoE',
        'Categoría': 'Ñapa',
        'Tipo': 'Supervisada',
        'Ventaja': 'Escala interpretable; selección y transformación simultáneas; ideal para regresión logística',
        'Limitación': 'Solo para target binario; requiere discretización previa'
    },
])

resumen.style.set_properties(**{'text-align': 'left', 'font-size': '12px'}) \
    .set_table_styles([{'selector': 'th', 'props': 'text-align: center; background-color: #003865; color: white;'}])
# Out:
# <style type="text/css">
# #T_44a6e th {
#   text-align: center;
#   background-color: #003865;
#   color: white;
# }
# #T_44a6e_row0_col0, #T_44a6e_row0_col1, #T_44a6e_row0_col2, #T_44a6e_row0_col3, #T_44a6e_row0_col4, #T_44a6e_row1_col0, #T_44a6e_row1_col1, #T_44a6e_row1_col2, #T_44a6e_row1_col3, #T_44a6e_row1_col4, #T_44a6e_row2_col0, #T_44a6e_row2_col1, #T_44a6e_row2_col2, #T_44a6e_row2_col3, #T_44a6e_row2_col4, #T_44a6e_row3_col0, #T_44a6e_row3_col1, #T_44a6e_row3_col2, #T_44a6e_row3_col3, #T_44a6e_row3_col4, #T_44a6e_row4_col0, #T_44a6e_row4_col1, #T_44a6e_row4_col2, #T_44a6e_row4_col3, #T_44a6e_row4_col4, #T_44a6e_row5_col0, #T_44a6e_row5_col1, #T_44a6e_row5_col2, #T_44a6e_row5_col3, #T_44a6e_row5_col4, #T_44a6e_row6_col0, #T_44a6e_row6_col1, #T_44a6e_row6_col2, #T_44a6e_row6_col3, #T_44a6e_row6_col4, #T_44a6e_row7_col0, #T_44a6e_row7_col1, #T_44a6e_row7_col2, #T_44a6e_row7_col3, #T_44a6e_row7_col4, #T_44a6e_row8_col0, #T_44a6e_row8_col1, #T_44a6e_row8_col2, #T_44a6e_row8_col3, #T_44a6e_row8_col4, #T_44a6e_row9_col0, #T_44a6e_row9_col1, #T_44a6e_row9_col2, #T_44a6e_row9_col3, #T_44a6e_row9_col4, #T_44a6e_row10_col0, #T_44a6e_row10_col1, #T_44a6e_row10_col2, #T_44a6e_row10_col3, #T_44a6e_row10_col4, #T_44a6e_row11_col0, #T_44a6e_row11_col1, #T_44a6e_row11_col2, #T_44a6e_row11_col3, #T_44a6e_row11_col4, #T_44a6e_row12_col0, #T_44a6e_row12_col1, #T_44a6e_row12_col2, #T_44a6e_row12_col3, #T_44a6e_row12_col4, #T_44a6e_row13_col0, #T_44a6e_row13_col1, #T_44a6e_row13_col2, #T_44a6e_row13_col3, #T_44a6e_row13_col4 {
#   text-align: left;
#   font-size: 12px;
# }
# </style>
# <table id="T_44a6e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_44a6e_level0_col0" class="col_heading level0 col0" >Técnica</th>
#       <th id="T_44a6e_level0_col1" class="col_heading level0 col1" >Categoría</th>
#       <th id="T_44a6e_level0_col2" class="col_heading level0 col2" >Tipo</th>
#       <th id="T_44a6e_level0_col3" class="col_heading level0 col3" >Ventaja</th>
#       <th id="T_44a6e_level0_col4" class="col_heading level0 col4" >Limitación</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_44a6e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_44a6e_row0_col0" class="data row0 col0" >Eliminar columnas con nulos</td>
#       <td id="T_44a6e_row0_col1" class="data row0 col1" >Reducción de Dimensionalidad</td>
#       <td id="T_44a6e_row0_col2" class="data row0 col2" >No supervisada</td>
#       <td id="T_44a6e_row0_col3" class="data row0 col3" >Elimina ruido cuando no es posible imputar</td>
#       <td id="T_44a6e_row0_col4" class="data row0 col4" >Pérdida de información si el umbral es muy agresivo</td>
#     </tr>
#     <tr>
#       <th id="T_44a6e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_44a6e_row1_col0" class="data row1 col0" >Low Variance Filter</td>
#       <td id="T_44a6e_row1_col1" class="data row1 col1" >Reducción de Dimensionalidad</td>
#       <td id="T_44a6e_row1_col2" class="data row1 col2" >No supervisada</td>
#       <td id="T_44a6e_row1_col3" class="data row1 col3" >Sencillo y rápido</td>
#       <td id="T_44a6e_row1_col4" class="data row1 col4" >Solo aplica a variables numéricas; requiere normalizar</td>
#     </tr>
#     <tr>
#       <th id="T_44a6e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_44a6e_row2_col0" class="data row2 col0" >Eliminación de correlacionadas</td>
#       <td id="T_44a6e_row2_col1" class="data row2 col1" >Reducción de Dimensionalidad</td>
#       <td id="T_44a6e_row2_col2" class="data row2 col2" >No supervisada</td>
#       <td id="T_44a6e_row2_col3" class="data row2 col3" >Elimina redundancia sin perder información</td>
#       <td id="T_44a6e_row2_col4" class="data row2 col4" >No captura relaciones no lineales</td>
#     </tr>
#     <tr>
#       <th id="T_44a6e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_44a6e_row3_col0" class="data row3 col0" >Random Forest VarImp</td>
#       <td id="T_44a6e_row3_col1" class="data row3 col1" >Reducción de Dimensionalidad</td>
#       <td id="T_44a6e_row3_col2" class="data row3 col2" >Supervisada</td>
#       <td id="T_44a6e_row3_col3" class="data row3 col3" >Captura relaciones no lineales; robusto</td>
#       <td id="T_44a6e_row3_col4" class="data row3 col4" >Computacionalmente costoso; sesgado a variables con más categorías</td>
#     </tr>
#     <tr>
#       <th id="T_44a6e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_44a6e_row4_col0" class="data row4 col0" >PCA</td>
#       <td id="T_44a6e_row4_col1" class="data row4 col1" >Reducción de Dimensionalidad</td>
#       <td id="T_44a6e_row4_col2" class="data row4 col2" >No supervisada</td>
#       <td id="T_44a6e_row4_col3" class="data row4 col3" >Reduce dimensiones manteniendo máxima varianza; útil para visualización</td>
#       <td id="T_44a6e_row4_col4" class="data row4 col4" >Componentes no interpretables; solo para variables numéricas</td>
#     </tr>
#     <tr>
#       <th id="T_44a6e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_44a6e_row5_col0" class="data row5 col0" >Normalización Min-Max</td>
#       <td id="T_44a6e_row5_col1" class="data row5 col1" >Ingeniería de Características</td>
#       <td id="T_44a6e_row5_col2" class="data row5 col2" >No supervisada</td>
#       <td id="T_44a6e_row5_col3" class="data row5 col3" >Rango fijo [0, 1]; intuitivo</td>
#       <td id="T_44a6e_row5_col4" class="data row5 col4" >Muy sensible a outliers</td>
#     </tr>
#     <tr>
#       <th id="T_44a6e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_44a6e_row6_col0" class="data row6 col0" >Normalización Z-Score</td>
#       <td id="T_44a6e_row6_col1" class="data row6 col1" >Ingeniería de Características</td>
#       <td id="T_44a6e_row6_col2" class="data row6 col2" >No supervisada</td>
#       <td id="T_44a6e_row6_col3" class="data row6 col3" >Estándar estadístico; amplamente usado</td>
#       <td id="T_44a6e_row6_col4" class="data row6 col4" >Asume distribución aproximadamente normal</td>
#     </tr>
#     <tr>
#       <th id="T_44a6e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_44a6e_row7_col0" class="data row7 col0" >Decimal Scaling</td>
#       <td id="T_44a6e_row7_col1" class="data row7 col1" >Ingeniería de Características</td>
#       <td id="T_44a6e_row7_col2" class="data row7 col2" >No supervisada</td>
#       <td id="T_44a6e_row7_col3" class="data row7 col3" >Simple; mantiene la estructura decimal</td>
#       <td id="T_44a6e_row7_col4" class="data row7 col4" >El rango resultante depende del máximo absoluto</td>
#     </tr>
#     <tr>
#       <th id="T_44a6e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_44a6e_row8_col0" class="data row8 col0" >Escalado Robusto</td>
#       <td id="T_44a6e_row8_col1" class="data row8 col1" >Ingeniería de Características</td>
#       <td id="T_44a6e_row8_col2" class="data row8 col2" >No supervisada</td>
#       <td id="T_44a6e_row8_col3" class="data row8 col3" >Resistente a outliers (usa mediana e IQR)</td>
#       <td id="T_44a6e_row8_col4" class="data row8 col4" >Sin rango fijo de salida</td>
#     </tr>
#     <tr>
#       <th id="T_44a6e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_44a6e_row9_col0" class="data row9 col0" >Binning Igual Ancho</td>
#       <td id="T_44a6e_row9_col1" class="data row9 col1" >Ingeniería de Características</td>
#       <td id="T_44a6e_row9_col2" class="data row9 col2" >No supervisada</td>
#       <td id="T_44a6e_row9_col3" class="data row9 col3" >Fácil de interpretar</td>
#       <td id="T_44a6e_row9_col4" class="data row9 col4" >Bins desbalanceados si la distribución es sesgada</td>
#     </tr>
#     <tr>
#       <th id="T_44a6e_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_44a6e_row10_col0" class="data row10 col0" >Binning Igual Frecuencia</td>
#       <td id="T_44a6e_row10_col1" class="data row10 col1" >Ingeniería de Características</td>
#       <td id="T_44a6e_row10_col2" class="data row10 col2" >No supervisada</td>

# %% [markdown]
# ---
# ## 6. Ñapa: Information Value (IV) y Weight of Evidence (WoE)
#
# ### ¿Qué es el Information Value?
#
# El **Information Value (IV)** es una métrica **supervisada** que mide la capacidad predictiva de una variable respecto a una variable objetivo **binaria**. Proviene del mundo del scoring crediticio pero se usa ampliamente en selección de variables para clasificación binaria.
#
# Se calcula a partir del **Weight of Evidence (WoE)** de cada categoría o bin de la variable:
#
# $$\text{WoE}_i = \ln\left(\frac{\% \text{Eventos}_i}{\% \text{No Eventos}_i}\right)$$
#
# $$\text{IV} = \sum_{i=1}^{k} \left(\% \text{Eventos}_i - \% \text{No Eventos}_i\right) \times \text{WoE}_i$$
#
# Donde:
# - **Evento** = clase positiva (p. ej. `1`, el resultado de interés).
# - **No Evento** = clase negativa (p. ej. `0`).
# - El índice $i$ recorre cada categoría o bin de la variable predictora.
#
# ### Interpretación del IV
#
# | IV | Poder Predictivo |
# |----|------------------|
# | < 0.02 | Inútil / sin poder predictivo |
# | 0.02 – 0.10 | Débil |
# | 0.10 – 0.30 | Medio |
# | 0.30 – 0.50 | Fuerte |
# | > 0.50 | Sospechoso (posible data leakage) |
#
# > ⚠️ **Requisitos:**
# > 1. La variable objetivo debe ser **binaria** (0/1).
# > 2. La variable predictora debe estar **discretizada** (bins) antes de calcular WoE/IV.
# > 3. Ningún bin debe tener 0 eventos o 0 no-eventos (se usa suavizado).
#
# ### Adaptación a Iris (multiclase → binaria)
#
# Iris tiene 3 clases. Para demostrar IV haremos dos adaptaciones:
# - **Caso A:** `setosa` (1) vs. `resto` (0) → clasificación binaria fácil.
# - **Caso B:** `virginica` (1) vs. `resto` (0) → clasificación binaria más difícil.

# %%
# ── Funciones para calcular WoE e IV ──────────────────────────────────────────

def calcular_woe_iv(df_input, feature, target, epsilon=0.5):
    """
    Calcula el Weight of Evidence (WoE) y el Information Value (IV)
    para una variable predictora respecto a un target binario (0/1).

    Parámetros
    ----------
    df_input : DataFrame con la variable predictora y el target.
    feature  : nombre de la columna predictora (ya discretizada).
    target   : nombre de la columna objetivo binaria (0/1).
    epsilon  : suavizado para evitar log(0) cuando un bin tiene 0 eventos.

    Retorna
    -------
    tabla_woe : DataFrame con WoE e IV parcial por bin.
    iv_total  : float, IV total de la variable.
    """
    total_eventos    = df_input[target].sum() + epsilon
    total_no_eventos = (1 - df_input[target]).sum() + epsilon

    tabla = (
        df_input.groupby(feature)[target]
        .agg(
            n_total='count',
            n_eventos='sum'
        )
        .reset_index()
    )
    tabla['n_no_eventos'] = tabla['n_total'] - tabla['n_eventos']

    # Suavizado para bins con cero
    tabla['n_eventos']    = tabla['n_eventos']    + epsilon
    tabla['n_no_eventos'] = tabla['n_no_eventos'] + epsilon

    tabla['pct_eventos']    = tabla['n_eventos']    / total_eventos
    tabla['pct_no_eventos'] = tabla['n_no_eventos'] / total_no_eventos

    tabla['WoE']     = np.log(tabla['pct_eventos'] / tabla['pct_no_eventos'])
    tabla['IV_parcial'] = (tabla['pct_eventos'] - tabla['pct_no_eventos']) * tabla['WoE']

    iv_total = tabla['IV_parcial'].sum()
    return tabla.round(4), round(iv_total, 4)


def clasificar_iv(iv):
    """Devuelve la etiqueta de poder predictivo según el IV."""
    if iv < 0.02:  return '🔴 Inútil'
    if iv < 0.10:  return '🟠 Débil'
    if iv < 0.30:  return '🟡 Medio'
    if iv < 0.50:  return '🟢 Fuerte'
    return '⚠️ Sospechoso (posible data leakage)'


print('✅ Funciones WoE / IV definidas.')
# Out:
# ✅ Funciones WoE / IV definidas.

# %%
# ── Preparar los dos escenarios binarios ──────────────────────────────────────
df_iv = df[iris.feature_names + ['species_name']].copy()

# Caso A: setosa (1) vs. resto (0)
df_iv['target_setosa']   = (df_iv['species_name'] == 'setosa').astype(int)

# Caso B: virginica (1) vs. resto (0)
df_iv['target_virginica'] = (df_iv['species_name'] == 'virginica').astype(int)

print('Distribución Caso A — setosa vs. resto:')
print(df_iv['target_setosa'].value_counts().to_string())
print()
print('Distribución Caso B — virginica vs. resto:')
print(df_iv['target_virginica'].value_counts().to_string())
# Out:
# Distribución Caso A — setosa vs. resto:
# target_setosa
# 0    100
# 1     50
#
# Distribución Caso B — virginica vs. resto:
# target_virginica
# 0    100
# 1     50

# %%
# ── Discretizar todas las variables numéricas con igual frecuencia (5 bins) ───
# WoE/IV requiere variables discretizadas
N_BINS_IV = 5
kbd_iv = KBinsDiscretizer(n_bins=N_BINS_IV, encode='ordinal', strategy='quantile')

X_disc = kbd_iv.fit_transform(df_iv[iris.feature_names])
for i, feat in enumerate(iris.feature_names):
    df_iv[feat + '_bin'] = X_disc[:, i].astype(int)

# Mostrar bordes de bins de una variable
print(f'Bordes de bins para "{iris.feature_names[2]}":')
print(kbd_iv.bin_edges_[2].round(3))
print()
print('Primeras 5 filas con bins:')
bin_cols = [f + '_bin' for f in iris.feature_names]
df_iv[iris.feature_names + bin_cols].head()
# Out:
# Bordes de bins para "petal length (cm)":
# [1.   1.5  3.9  4.64 5.32 6.9 ]
#
# Primeras 5 filas con bins:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    sepal length (cm)_bin  sepal width (cm)_bin  petal length (cm)_bin  \
# 0                      1                     4                      0
# 1                      0                     2                      0
# 2                      0                     3                      0
# 3                      0                     3                      1
# 4                      1                     4                      0
#
#    petal width (cm)_bin
# 0                     1
# 1                     1
# 2                     1
# 3                     1
# 4                     1

# %% [markdown]
# #### Caso A: `setosa` (1) vs. `resto` (0)

# %%
# Calcular IV de cada variable para Caso A
print('=' * 55)
print('  CASO A — setosa (1) vs. resto (0)')
print('=' * 55)

iv_resumen_a = []
for feat in iris.feature_names:
    tabla_woe, iv_total = calcular_woe_iv(
        df_iv, feat + '_bin', 'target_setosa'
    )
    iv_resumen_a.append({
        'Variable': feat,
        'IV': iv_total,
        'Poder Predictivo': clasificar_iv(iv_total)
    })

iv_df_a = pd.DataFrame(iv_resumen_a).sort_values('IV', ascending=False).reset_index(drop=True)
iv_df_a
# Out:
# =======================================================
#   CASO A — setosa (1) vs. resto (0)
# =======================================================
#             Variable      IV                      Poder Predictivo
# 0  petal length (cm)  6.1052  ⚠️ Sospechoso (posible data leakage)
# 1   petal width (cm)  5.0568  ⚠️ Sospechoso (posible data leakage)
# 2  sepal length (cm)  4.1247  ⚠️ Sospechoso (posible data leakage)
# 3   sepal width (cm)  2.4295  ⚠️ Sospechoso (posible data leakage)

# %%
# Tabla WoE detallada de la variable con mayor IV (Caso A)
mejor_var_a = iv_df_a.loc[0, 'Variable']
tabla_woe_a, iv_a = calcular_woe_iv(df_iv, mejor_var_a + '_bin', 'target_setosa')

print(f'Tabla WoE — "{mejor_var_a}"  |  IV = {iv_a}  |  {clasificar_iv(iv_a)}')
print()
tabla_woe_a[[
    mejor_var_a + '_bin', 'n_total', 'n_eventos', 'n_no_eventos',
    'pct_eventos', 'pct_no_eventos', 'WoE', 'IV_parcial'
]]
# Out:
# Tabla WoE — "petal length (cm)"  |  IV = 6.1052  |  ⚠️ Sospechoso (posible data leakage)
#    petal length (cm)_bin  n_total  n_eventos  n_no_eventos  pct_eventos  \
# 0                      0       24       24.5           0.5       0.4851
# 1                      1       34       26.5           8.5       0.5248
# 2                      2       32        0.5          32.5       0.0099
# 3                      3       30        0.5          30.5       0.0099
# 4                      4       30        0.5          30.5       0.0099
#
#    pct_no_eventos     WoE  IV_parcial
# 0          0.0050  4.5800      2.1992
# 1          0.0846  1.8253      0.8034
# 2          0.3234 -3.4862      1.0929
# 3          0.3035 -3.4227      1.0048
# 4          0.3035 -3.4227      1.0048

# %% [markdown]
# #### Caso B: `virginica` (1) vs. `resto` (0)

# %%
print('=' * 55)
print('  CASO B — virginica (1) vs. resto (0)')
print('=' * 55)

iv_resumen_b = []
for feat in iris.feature_names:
    tabla_woe, iv_total = calcular_woe_iv(
        df_iv, feat + '_bin', 'target_virginica'
    )
    iv_resumen_b.append({
        'Variable': feat,
        'IV': iv_total,
        'Poder Predictivo': clasificar_iv(iv_total)
    })

iv_df_b = pd.DataFrame(iv_resumen_b).sort_values('IV', ascending=False).reset_index(drop=True)
iv_df_b
# Out:
# =======================================================
#   CASO B — virginica (1) vs. resto (0)
# =======================================================
#             Variable      IV                      Poder Predictivo
# 0   petal width (cm)  6.1815  ⚠️ Sospechoso (posible data leakage)
# 1  petal length (cm)  5.8050  ⚠️ Sospechoso (posible data leakage)
# 2  sepal length (cm)  2.5942  ⚠️ Sospechoso (posible data leakage)
# 3   sepal width (cm)  0.3485                              🟢 Fuerte

# %% [markdown]
# #### Visualización: IV comparativo y curvas WoE

# %%
# ── Gráfica 1: IV de todas las variables en los dos escenarios ────────────────
fig, axes = plt.subplots(1, 2, figsize=(13, 4), sharey=True)

umbrales = [
    (0.02, 'Inútil',    '#e0e0e0'),
    (0.10, 'Débil',     '#ffccbc'),
    (0.30, 'Medio',     '#fff9c4'),
    (0.50, 'Fuerte',    '#c8e6c9'),
]

for ax, iv_df, titulo in zip(
    axes,
    [iv_df_a, iv_df_b],
    ['Caso A: setosa vs. resto', 'Caso B: virginica vs. resto']
):
    colores_bar = [
        '#1565C0' if iv >= 0.30 else '#42A5F5' if iv >= 0.10 else '#90CAF9'
        for iv in iv_df['IV']
    ]
    bars = ax.barh(iv_df['Variable'], iv_df['IV'], color=colores_bar, edgecolor='white')
    for bar, iv_val in zip(bars, iv_df['IV']):
        ax.text(
            bar.get_width() + 0.01, bar.get_y() + bar.get_height() / 2,
            f'{iv_val:.3f}', va='center', fontsize=9
        )
    # Líneas de referencia
    for val, lbl, _ in umbrales:
        ax.axvline(val, color='gray', linestyle=':', linewidth=0.8, alpha=0.7)
        ax.text(val + 0.002, -0.6, lbl, fontsize=7, color='gray')
    ax.set_title(titulo, fontsize=11)
    ax.set_xlabel('Information Value (IV)')
    ax.invert_yaxis()

fig.suptitle('Information Value por Variable y Escenario', fontsize=13)
plt.tight_layout()
plt.show()

# %%
# ── Gráfica 2: Curvas WoE para cada variable (Caso A) ────────────────────────
fig, axes = plt.subplots(1, 4, figsize=(16, 4))

for ax, feat in zip(axes, iris.feature_names):
    tabla_w, iv_t = calcular_woe_iv(df_iv, feat + '_bin', 'target_setosa')
    bin_labels = [f'bin {int(b)}' for b in tabla_w[feat + '_bin']]

    colores_woe = ['#EF5350' if w < 0 else '#42A5F5' for w in tabla_w['WoE']]
    ax.bar(bin_labels, tabla_w['WoE'], color=colores_woe, edgecolor='white')
    ax.axhline(0, color='black', linewidth=0.8)
    ax.set_title(f'{feat.replace(" (cm)","")}\nIV = {iv_t}', fontsize=9)
    ax.set_ylabel('WoE' if ax == axes[0] else '')
    ax.tick_params(axis='x', labelsize=8)

fig.suptitle('Weight of Evidence por bin — Caso A (setosa vs. resto)', fontsize=12)
plt.tight_layout()
plt.show()

print('\n📌 WoE positivo → el bin tiene más "eventos" (setosas) de lo esperado.')
print('   WoE negativo → el bin tiene menos "eventos" de lo esperado.')
# Out:
# 📌 WoE positivo → el bin tiene más "eventos" (setosas) de lo esperado.
#    WoE negativo → el bin tiene menos "eventos" de lo esperado.

# %%
# ── Selección de variables según umbral de IV ─────────────────────────────────
UMBRAL_IV = 0.10  # Conservar variables con IV >= 0.10 (poder medio o superior)

print(f'Umbral IV aplicado: {UMBRAL_IV}  →  conservar variables con poder "Medio" o superior\n')

for caso, iv_df, nombre in [
    ('A', iv_df_a, 'setosa vs. resto'),
    ('B', iv_df_b, 'virginica vs. resto')
]:
    seleccionadas = iv_df.query('IV >= @UMBRAL_IV')['Variable'].tolist()
    descartadas   = iv_df.query('IV <  @UMBRAL_IV')['Variable'].tolist()
    print(f'Caso {caso} ({nombre}):')
    print(f'  ✅ Seleccionadas : {seleccionadas}')
    print(f'  ❌ Descartadas   : {descartadas}')
    print()
# Out:
# Umbral IV aplicado: 0.1  →  conservar variables con poder "Medio" o superior
#
# Caso A (setosa vs. resto):
#   ✅ Seleccionadas : ['petal length (cm)', 'petal width (cm)', 'sepal length (cm)', 'sepal width (cm)']
#   ❌ Descartadas   : []
#
# Caso B (virginica vs. resto):
#   ✅ Seleccionadas : ['petal width (cm)', 'petal length (cm)', 'sepal length (cm)', 'sepal width (cm)']
#   ❌ Descartadas   : []

# %% [markdown]
# #### ¿Para qué se usa WoE en la práctica?
#
# El WoE tiene un uso adicional importante: **transformar** las variables originales reemplazando cada categoría por su valor WoE. Esto es útil porque:
#
# 1. Convierte variables categóricas en numéricas con una escala significativa (a diferencia de One-Hot Encoding, no aumenta la dimensionalidad).
# 2. Linealiza la relación entre el predictor y el log-odds de la variable objetivo → ideal para regresión logística.
# 3. Maneja automáticamente categorías con pocos datos (suavizado `epsilon`).

# %%
# ── Transformación WoE de todas las variables (Caso A) ────────────────────────
df_woe = df_iv[iris.feature_names + ['target_setosa']].copy()

for feat in iris.feature_names:
    tabla_w, _ = calcular_woe_iv(df_iv, feat + '_bin', 'target_setosa')
    # Mapa bin → WoE
    mapa_woe = dict(zip(tabla_w[feat + '_bin'], tabla_w['WoE']))
    df_woe[feat + '_woe'] = df_iv[feat + '_bin'].map(mapa_woe)

woe_cols = [f + '_woe' for f in iris.feature_names]
print('Primeras 10 filas — variables transformadas a WoE:')
df_woe[iris.feature_names + woe_cols].head(10).round(3)
# Out:
# Primeras 10 filas — variables transformadas a WoE:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
# 5                5.4               3.9                1.7               0.4
# 6                4.6               3.4                1.4               0.3
# 7                5.0               3.4                1.5               0.2
# 8                4.4               2.9                1.4               0.2
# 9                4.9               3.1                1.5               0.1
#
#    sepal length (cm)_woe  sepal width (cm)_woe  petal length (cm)_woe  \
# 0                  1.651                 2.266                  4.580
# 1                  2.792                -0.460                  4.580
# 2                  2.792                 0.160                  4.580
# 3                  2.792                 0.160                  1.825
# 4                  1.651                 2.266                  4.580
# 5                  1.651                 2.266                  1.825
# 6                  2.792                 2.266                  4.580
# 7                  1.651                 2.266                  1.825
# 8                  2.792                -2.388                  4.580
# 9                  2.792                 0.160                  1.825
#
#    petal width (cm)_woe
# 0                 2.154
# 1                 2.154
# 2                 2.154
# 3                 2.154
# 4                 2.154
# 5                 2.154
# 6                 2.154
# 7                 2.154
# 8                 2.154
# 9                 3.086

# %%
# ── Resumen final IV ──────────────────────────────────────────────────────────
print('╔══════════════════════════════════════════════════════════╗')
print('║           RESUMEN — Information Value (IV)               ║')
print('╠══════════════════════════════════════════════════════════╣')
print('║  Caso A: setosa vs. resto                                ║')
for _, row in iv_df_a.iterrows():
    print(f'║    {row["Variable"]:<28}  IV = {row["IV"]:.3f}  {row["Poder Predictivo"]} ║')
print('╠══════════════════════════════════════════════════════════╣')
print('║  Caso B: virginica vs. resto                             ║')
for _, row in iv_df_b.iterrows():
    print(f'║    {row["Variable"]:<28}  IV = {row["IV"]:.3f}  {row["Poder Predictivo"]} ║')
print('╚══════════════════════════════════════════════════════════╝')
print()
print('📌 Interpretación:')
print('   · Caso A: petal length y petal width son altamente predictivas de setosa.')
print('   · Caso B: las mismas variables distinguen bien virginica del resto,')
print('     pero con IVs menores porque la separación es menos perfecta.')
# Out:
# ╔══════════════════════════════════════════════════════════╗
# ║           RESUMEN — Information Value (IV)               ║
# ╠══════════════════════════════════════════════════════════╣
# ║  Caso A: setosa vs. resto                                ║
# ║    petal length (cm)             IV = 6.105  ⚠️ Sospechoso (posible data leakage) ║
# ║    petal width (cm)              IV = 5.057  ⚠️ Sospechoso (posible data leakage) ║
# ║    sepal length (cm)             IV = 4.125  ⚠️ Sospechoso (posible data leakage) ║
# ║    sepal width (cm)              IV = 2.429  ⚠️ Sospechoso (posible data leakage) ║
# ╠══════════════════════════════════════════════════════════╣
# ║  Caso B: virginica vs. resto                             ║
# ║    petal width (cm)              IV = 6.181  ⚠️ Sospechoso (posible data leakage) ║
# ║    petal length (cm)             IV = 5.805  ⚠️ Sospechoso (posible data leakage) ║
# ║    sepal length (cm)             IV = 2.594  ⚠️ Sospechoso (posible data leakage) ║
# ║    sepal width (cm)              IV = 0.348  🟢 Fuerte ║
# ╚══════════════════════════════════════════════════════════╝
#
# 📌 Interpretación:
#    · Caso A: petal length y petal width son altamente predictivas de setosa.
#    · Caso B: las mismas variables distinguen bien virginica del resto,
#      pero con IVs menores porque la separación es menos perfecta.

# %% [markdown]
# #### IV vs. otras métricas de selección de variables
#
# | Métrica | Tipo | Target requerido | Variables | Interpretable |
# |---------|------|-----------------|-----------|---------------|
# | Low Variance Filter | No supervisada | No | Numéricas | Sí |
# | Correlación de Pearson | No supervisada | No | Numéricas | Sí |
# | Chi-cuadrado | No supervisada / supervisada | Opcional | Categóricas | Moderado |
# | Random Forest VarImp | Supervisada | Sí (multiclase OK) | Numéricas y categ. | Moderado |
# | **Information Value (IV)** | **Supervisada** | **Sí (solo binario)** | **Numéricas (binneadas) y categ.** | **Sí — escala intuitiva** |
#
# > 💡 **Cuándo usar IV:** cuando tu objetivo es binario (fraude/no fraude, churn/no churn, default/no default) y quieres una métrica sencilla de explicar a stakeholders no técnicos.

# %% [markdown]
# ---
# ## 🎯 Ejercicios propuestos
#
# 1. **Correlación con chi-cuadrado:** la sección 3.3 usó correlación de Pearson (variables continuas). Aplica una prueba chi-cuadrado para evaluar la dependencia entre `petal_length_entropia` (variable discretizada) y `species_name`. ¿Cuál es tu conclusión?
#
# 2. **Selección Forward:** implementa una selección forward usando como métrica la exactitud (*accuracy*) de un árbol de decisión. Empieza con el conjunto vacío e itera hasta no mejorar el desempeño.
#
# 3. **Comparación de normalizaciones en KNN:** usa las versiones normalizadas de las variables para entrenar un KNN y compara la exactitud con la versión sin normalizar. ¿Qué método de normalización da mejores resultados?
#
# 4. **PCA 3D:** proyecta los datos en 3 componentes y genera un gráfico 3D usando `matplotlib` con `Axes3D`. ¿Cuánta varianza adicional captura PC3 sobre PC2?
#
# 5. **Efecto del binning en un clasificador:** entrena un árbol de decisión usando `petal_length_igulancho_lbl` y otro con `petal_length_entropia`. ¿Cuál tiene mayor *accuracy*? ¿Por qué?
#
# 6. **IV con diferente número de bins:** recalcula el IV de `petal length (cm)` para el Caso A variando el número de bins (3, 5, 7 y 10). ¿Cómo cambia el IV? ¿A partir de cuántos bins el IV se estabiliza?
#
# 7. **WoE en regresión logística:** usa las variables transformadas a WoE (`_woe`) del Caso A para entrenar una regresión logística. Compara la exactitud con la versión entrenada sobre las variables originales.
#
# ---
# *Fin del notebook — Semana 7 | Introducción a la Minería de Datos*
